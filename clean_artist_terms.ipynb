# %%
import pandas as pd

# %%
df = pd.read_csv('./big_subset.csv')
#df["artist_terms_array"] = ""

# %%
df.head()
# Out:
#    analysis_sample_rate  artist_familiarity  artist_hotttnesss  \
# 0                 22050            0.647934           0.482023
# 1                 22050            0.609093           0.492579
# 2                 22050            0.531736           0.409133
# 3                 22050            0.437903           0.307584
# 4                 22050            0.672271           0.448150
#
#             artist_id  artist_latitude     artist_location  artist_longitude  \
# 0  AR4PQ891187FB5CA9F         40.76099     East Orange, NJ         -74.20991
# 1  AR8LHSZ1187B9A1025              NaN                 NaN               NaN
# 2  AR35ZU21187B9B65FC         57.15382  Aberdeen, Scotland          -2.10679
# 3  AR7B98Y1187B98F5F3         37.27188          California        -119.27023
# 4  AROZIQ01187B9AF514              NaN                 NaN               NaN
#
#       artist_name                                       artist_terms  \
# ...

# %%
words = df['artist_terms'][0].split("\n")
descr = []
for word in words:
    wo = word.split("' '")
    for w in wo:
        descr.append(w)
zmod = [zz.replace('\'', '').replace('[', '').replace(']', '').strip() for zz in descr]

# %%
df.at[0,'artist_terms'] = zmod
#z_string = ', '.join(zmod)
#df.at[0,'artist_terms'] = z_string

# %%
len(df)
# Out:
# 170218

# %%
for i in range(len(df)):
    words = df['artist_terms'][i].split("\n")
    descr = []
    for word in words:
        wo = word.split("' '")
        for w in wo:
            descr.append(w)
    zmod = [zz.replace('\'', '').replace('[', '').replace(']', '').strip() for zz in descr]
    df.at[i,'artist_terms'] = zmod

# %%
df.head()
# Out:
#    analysis_sample_rate  artist_familiarity  artist_hotttnesss  \
# 0                 22050            0.647934           0.482023
# 1                 22050            0.609093           0.492579
# 2                 22050            0.531736           0.409133
# 3                 22050            0.437903           0.307584
# 4                 22050            0.672271           0.448150
#
#             artist_id  artist_latitude     artist_location  artist_longitude  \
# 0  AR4PQ891187FB5CA9F         40.76099     East Orange, NJ         -74.20991
# 1  AR8LHSZ1187B9A1025              NaN                 NaN               NaN
# 2  AR35ZU21187B9B65FC         57.15382  Aberdeen, Scotland          -2.10679
# 3  AR7B98Y1187B98F5F3         37.27188          California        -119.27023
# 4  AROZIQ01187B9AF514              NaN                 NaN               NaN
#
#       artist_name                                       artist_terms  \
# ...

# %%
df.to_csv('clean_big_subset.csv')
