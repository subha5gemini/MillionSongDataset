# %%
#load Spark
import findspark
findspark.init()

from pyspark import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext()
ss = SparkSession.builder.appName("project1").getOrCreate()

# %%
import pandas as pd
temp = pd.read_csv("s3://cosc502millionsong/df_test_2.csv")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/miniconda/lib/python3.7/site-packages/s3fs/core.py in _lsdir(self, path, refresh, max_items)
#     333                 dircache = []
# --> 334                 for i in it:
#     335                     dircache.extend(i.get('CommonPrefixes', []))
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in __iter__(self)
#     254         while True:
# --> 255             response = self._make_request(current_kwargs)
#     256             parsed = self._extract_parsed_response(response)
#
# ~/miniconda/lib/python3.7/site-packages/botocore/paginate.py in _make_request(self, current_kwargs)
#     331     def _make_request(self, current_kwargs):
# --> 332         return self._method(**current_kwargs)
#     333
#
# ~/miniconda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
# ...

# %%
df = spark.read.format("csv").option("inferSchema", 
           True).option("header", True).load(file_location)
display(df)
